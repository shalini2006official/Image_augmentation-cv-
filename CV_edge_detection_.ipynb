# %% [markdown]
# <a href="https://colab.research.google.com/github/shalini2006official/Image_augmentation-cv-/blob/main/CV_edge_detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
image = cv2.imread('/content/shinchan.jpg')

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) #convert color
edges = cv2.Canny(gray_image,50,100)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=L size=300x168>
